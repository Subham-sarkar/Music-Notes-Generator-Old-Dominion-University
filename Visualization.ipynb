# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('logs/training_log.csv')
df
# Out:
#      epoch      loss       acc
# 0        1  2.487137  0.342621
# 1        2  1.538722  0.556241
# 2        3  1.292083  0.600299
# 3        4  1.178747  0.625579
# 4        5  1.108829  0.644693
# 5        6  1.055345  0.661882
# 6        7  1.011197  0.675593
# 7        8  0.974100  0.687564
# 8        9  0.938137  0.698293
# 9       10  0.909877  0.707484
# 10      11  0.884619  0.715962
# 11      12  0.861540  0.723100
# 12      13  0.841742  0.729048
# 13      14  0.825372  0.734090
# 14      15  0.808238  0.738964
# 15      16  0.792869  0.743451
# 16      17  0.776794  0.747923
# 17      18  0.765631  0.751246
# 18      19  0.751833  0.755261
# 19      20  0.738501  0.759509
# 20      21  0.726501  0.763758
# 21      22  0.715234  0.766730
# 22      23  0.704320  0.770210
# 23      24  0.696214  0.773009
# 24      25  0.686778  0.775678
# 25      26  0.678774  0.778530
# 26      27  0.669074  0.781069
# 27      28  0.661207  0.783890
# 28      29  0.651058  0.786789
# 29      30  0.646087  0.787909
# ..     ...       ...       ...
# 786    787  0.640240  0.787052
# 787    788  0.636988  0.787326
# 788    789  0.638713  0.786842
# 789    790  0.644673  0.785682
# 790    791  0.647932  0.784202
# 791    792  0.641313  0.785638
# 792    793  0.642404  0.785782
# 793    794  0.641793  0.786078
# 794    795  0.642675  0.785991
# 795    796  0.644848  0.784646
# 796    797  0.649155  0.783722
# 797    798  0.649469  0.783930
# 798    799  0.647804  0.784341
# 799    800  0.647394  0.784226
# 800    801  0.646201  0.784798
# 801    802  0.648880  0.783877
# 802    803  0.663667  0.779962
# 803    804  0.651035  0.783532
# 804    805  0.652130  0.782291
# 805    806  0.654662  0.782386
# 806    807  0.652060  0.782995
# 807    808  0.653410  0.782388
# 808    809  0.649195  0.784301
# 809    810  0.650285  0.783349
# 810    811  0.658574  0.781195
# 811    812  0.654560  0.781376
# 812    813  0.652528  0.781831
# 813    814  0.650572  0.783349
# 814    815  0.652540  0.783048
# 815    816  0.650770  0.782478
#
# [816 rows x 3 columns]

# %%
sns.set()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['loss'])
plt.title('Training Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['acc'])
plt.title('Training Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
